# %%
import json

def load_json(file):
    with open(file, encoding = "utf-8") as f:
        response = f.read()
        data = json.loads(response)
    
    return data

# Provide the file path to the Theme Versions JSON file
file_path = "/Users/karthikeyansaravanan/Downloads/Theme Discovery EM_ Anonymized Data/6_28_2023 Anonymized Theme Versions.json"

# %%
# Load the JSONL file into a list of dictionaries
themes = load_json(file_path)

# Perform further analysis on the 'annotations' data structure
# For example, iterate over the annotations and access specific fields
for themes in themes:
    # Access the desired fields of each annotation
    # Perform analysis or processing on the fields
    print(themes)
# Out:
# {'u__researchQuestionId': '9ACwoy9q8pGuFhrBDEog', 'u__teamId': '6d8ede62b922a4db674a1aacb2e18af298eb3fc4580110b9942f544a0f02d199', 'u__id': '4z8JUCcsAVTf7pRz0QgL', 'u__authorId': '77f8d59584fe1f65c74577cf31e7243f91358d8ae56eb68225ee7fcda3a4be4f', 'u_createdAt': '2023-04-10 22:01:01.468000 UTC', 'versionName': '8730fc6a9359e7442b3b8555d65e4a5902c37b5e184d5b62c061d1ca313cbabd', 'u__hiddenAnnotationIds': [], 'u_updatedAt': None, 'structure': [], '__key__': {'namespace': '', 'app': 's~annota-c8a75', 'path': '"themeVersions", "4z8JUCcsAVTf7pRz0QgL"', 'kind': 'themeVersions', 'name': '4z8JUCcsAVTf7pRz0QgL', 'id': None}, '__error__': [], '__has_error__': 'false'}
# ...
